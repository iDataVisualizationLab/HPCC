# %%
import zlib, json
import base64
from base64 import b64encode, b64decode

# %%
def json_unzip(j, insist=True):
    try:
        assert (j[ZIPJSON_KEY])
        assert (set(j.keys()) == {ZIPJSON_KEY})
    except:
        if insist:
            raise RuntimeError("JSON not in the expected format {" + str(ZIPJSON_KEY) + ": zipstring}")
        else:
            return j

    try:
        j = zlib.decompress(base64.b64decode(j[ZIPJSON_KEY]))
    except:
        print(j[ZIPJSON_KEY])
        raise RuntimeError("Could not decode/unzip the contents")

    try:
        j = json.loads(j)
    except:
        raise RuntimeError("Could interpret the unzipped contents")

    return j

# %%
import urllib.request

url = "http://129.118.104.141:8080/v1/metrics?start=2020-02-27T00%3A00%3A00Z&end=2020-02-28T00%3A00%3A00Z&interval=5m&value=max"
with urllib.request.urlopen(url) as url:
    data = json.loads(url.read())
    ZIPJSON_KEY = 'base64(zip(o))'
    for k in data:
        data[k] = json_unzip(data[k])
    print(data)
# Out:
# {'jobs_info': {'1156662': {'user_name': 'dmorenos', 'submit_time': 1582560330, 'start_time': 1582561644, 'job_array': False}, '1179519': {'user_name': 'daray', 'submit_time': 1582843291, 'start_time': 1582844011, 'job_array': False}, '1178529.91': {'user_name': 'matapatt', 'submit_time': 1582826559, 'start_time': 1582830083, 'job_array': True}, '1178529.887': {'user_name': 'matapatt', 'submit_time': 1582826559, 'start_time': 1582838639, 'job_array': True}, '1180299': {'user_name': 'abdumali', 'submit_time': 1582846122, 'start_time': 1582848825, 'job_array': False}, '1179549.6': {'user_name': 'qiu25856', 'submit_time': 1582844459, 'start_time': 1582844468, 'job_array': True}, '1177619.37': {'user_name': 'rmanser', 'submit_time': 1582777354, 'start_time': 1582778289, 'job_array': True}, '1178006': {'user_name': 'jacqurob', 'submit_time': 1582822468, 'start_time': 1582823043, 'job_array': False}, '1179549.24': {'user_name': 'qiu25856', 'submit_time': 1582844459, 'start_time': 1582844468, 'job_array': True}, '1179366.72': {'user_name': 'rmanser', 'submit_time': 1582841037, 'start_time': 1582841338, 'job_array': True}, '1179364.65': {'user_name': 'rmanser', 'submit_time': 1582841026, 'start_time': 1582841038, 'job_array': True}, '1182074.165': {'user_name': 'qiu25856', 'submit_time': 1582860085, 'start_time': 1582860196, 'job_array': True}, '1178528.133': {'user_name': 'matapatt', 'submit_time': 1582826241, 'start_time': 1582826690, 'job_array': True}, '1179369.31': {'user_name': 'rmanser', 'submit_time': 1582841081, 'start_time': 1582841771, 'job_array': True}, '1178526': {'user_name': 'iarsenea', 'submit_time': 1582825651, 'start_time': 1582825880, 'job_array': False}, '1178529.176': {'user_name': 'matapatt', 'submit_time': 1582826559, 'start_time': 1582830218, 'job_array': True}, '1179364.38': {'user_name': 'rmanser', 'submit_time': 1582841026, 'start_time': 1582841038, 'job_array': True}, '1179362.1': {'user_name': 'rmanser', 'submit_time': 1582841016, 'start_time': 1582841024, 'job_array': True}, '1178041': {'user_name': 'jacqurob', 'submit_time': 1582822488, 'start_time': 1582825881, 'job_array': False}, '1178528.442': {'user_name': 'matapatt', 'submit_time': 1582826241, 'start_time': 1582827999, 'job_array': True}, '1178528.571': {'user_name': 'matapatt', 'submit_time': 1582826241, 'start_time': 1582828573, 'job_array': True}, '1179549.109': {'user_name': 'qiu25856', 'submit_time': 1582844459, 'start_time': 1582844468, 'job_array': True}, '1179369.19': {'user_name': 'rmanser', 'submit_time': 1582841081, 'start_time': 1582841753, 'job_array': True}, '1178528.641': {'user_name': 'matapatt', 'submit_time': 1582826241, 'start_time': 1582828802, 'job_array': True}, '1178453': {'user_name': 'rirising', 'submit_time': 1582825328, 'start_time': 1582832072, 'job_array': False}, '1182155.48': {'user_name': 'rmanser', 'submit_time': 1582864583, 'start_time': 1582865566, 'job_array': True}, '1179549.70': {'user_name': 'qiu25856', 'submit_time': 1582844459, 'start_time': 1582844468, 'job_array': True}, '1179549.68': {'user_name': 'qiu25856', 'submit_time': 1582844459, 'start_time': 1582844468, 'job_array': True}, '1182074.59': {'user_name': 'qiu25856', 'submit_time': 1582860085, 'start_time': 1582860085, 'job_array': True}, '1178847': {'user_name': 'sisadegh', 'submit_time': 1582834402, 'start_time': 1582836016, 'job_array': False}, '1181160': {'user_name': 'emilwrig', 'submit_time': 1582849478, 'start_time': 1582851686, 'job_array': False}, '1176159': {'user_name': 'uozuguze', 'submit_time': 1582736504, 'start_time': 1582768856, 'job_array': False}, '1178529.388': {'user_name': 'matapatt', 'submit_time': 1582826559, 'start_time': 1582830690, 'job_array': True}, '1180385': {'user_name': 'abdumali', 'submit_time': 1582846132, 'start_time': 1582856573, 'job_array': False}, '1178528.996': {'user_name': 'matapatt', 'submit_time': 1582826241, 'start_time': 1582829780, 'job_array': True}, '1181890': {'user_name': 'tmengke', 'submit_time': 1582 ...
